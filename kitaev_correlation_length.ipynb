# %%
using QMOC
using DelimitedFiles
using Statistics
using CairoMakie
# Out:
# ERROR: LoadError: InitError: could not load library "/Users/danielsimm/.julia/artifacts/112745bebf2bab1be3313a35fda52d857c5b4ab4/lib/libavcodec.60.31.102.dylib"
# dlopen(/Users/danielsimm/.julia/artifacts/112745bebf2bab1be3313a35fda52d857c5b4ab4/lib/libavcodec.60.31.102.dylib, 0x0001): Library not loaded: @rpath/libssl.3.dylib
#   Referenced from: <AC4A15B4-4666-3B7C-BDA8-C16A0F12D3DC> /Users/danielsimm/.julia/artifacts/112745bebf2bab1be3313a35fda52d857c5b4ab4/lib/libavcodec.60.31.102.dylib
# ...
